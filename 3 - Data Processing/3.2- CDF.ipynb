# %% [markdown]
# ![](/Workspace/Users/sunnygupta2508@gmail.com/Databricks-Certified-Data-Engineer-Pro/Includes/images/CDF.png)

# %%
# %run ../Includes/Copy-Datasets

# %%
# %sql
select * from customers_silver

# %%
# %sql
alter table customers_silver set tblproperties(delta.enableChangeDataFeed = true);

# %%
# %sql
describe table extended customers_silver;

# %%
# %sql
DESCRIBE HISTORY customers_silver

# %%
bookstore.load_new_data()
bookstore.process_bronze()
bookstore.process_orders_silver()
bookstore.process_customers_silver()

# %%
# %sql
select *
from table_changes("customers_silver",2);

# %%
df = (
    spark.readStream
            .format("delta")
            .option("readChangeData", True)
            .option("startingVersion",2)
            .table("customers_silver")
            
)
display(df,checkpointLocation = f"{bookstore.dataset_path}/tmp/cdf_{time.time()}")
